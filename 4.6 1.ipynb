# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Importing data 
df_ords_prior = pd.read_csv(r'/Users/rayruslijunior/11-2021 Instacart Basket Analysis/02 Data/Original Data/order_products__prior.csv',index_col = False)

# %%
df_ords = pd.read_csv(r'/Users/rayruslijunior/11-2021 Instacart Basket Analysis/02 Data/Prepared Data/orders_cleaned.csv', index_col= False)

# %%
#checking df_ords_prior's output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
#checking df_ords_prior's shape
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
#and the shape of df_ords
df_ords.shape
# Out:
# (3421083, 9)

# %%
#Merging the prepared Instacart orders data with the new orders_products_prior dataframe per instruction
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id',how = 'outer', indicator = True)

# %%
df_merged_large
# Out:
#           Unnamed: 0  order_id  user_id  order_number  order_dow  \
# 0                  0   2539329        1             1          2
# 1                  0   2539329        1             1          2
# 2                  0   2539329        1             1          2
# 3                  0   2539329        1             1          2
# 4                  0   2539329        1             1          2
# ...              ...       ...      ...           ...        ...
# 32640693     3421081   2977660   206209            13          1
# 32640694     3421081   2977660   206209            13          1
# 32640695     3421081   2977660   206209            13          1
# 32640696     3421081   2977660   206209            13          1
# 32640697     3421082    272231   206209            14          6
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                         8                     NaN         True       196.0
# ...

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only       206209
# right_only           0
# Name: _merge, dtype: int64

# %%
# 2. Export the merged file in pickle format as “orders_products_combined.pkl”.
df_merged_large.to_pickle(r'/Users/rayruslijunior/11-2021 Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl')
