# %% [markdown]
# __4.7 Deriving New Variables __

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#importing order_product_merged.pki
df_orders_products_merged = pd.read_pickle(r'/Users/rayruslijunior/11-2021 Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged.pkl')

# %%
#limiting our dataframe to only 1.000.000
df= df_orders_products_merged[:1000000]

# %% [markdown]
# __Using If command__

# %%
#setting and definition for price_label collumn with an If condition
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# <ipython-input-9-fe64de1169c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df.shape
# Out:
# (1000000, 16)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    668114
# Low-range product    312168
# High range            12340
# Not enough data        7378
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# __Using Loc Command__

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /Users/rayruslijunior/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'
# Out:
# /Users/rayruslijunior/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# /Users/rayruslijunior/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     668114
# Low-range product     312168
# High-range product     12340
# NaN                     7378
# Name: price_range_loc, dtype: int64

# %% [markdown]
# __Let's use the entire data set now!__

# %%
ords_prods_merged = pd.read_pickle(r'/Users/rayruslijunior/11-2021 Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged.pkl')

# %%
ords_prods_merged.shape
# Out:
# (32641268, 15)

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] > 15,'price_range_loc'] = 'High-range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] <=15) & (ords_prods_merged['prices']>5),'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] <= 5,'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# NaN                     236409
# Name: price_range_loc, dtype: int64

# %% [raw]
# __If Statement with For Loops__

# %%
print("my age is 30")
# Out:
# my age is 30

# %%
print("my age is 31")
# Out:
# my age is 31

# %%
for x in range (30,45):
    print("my age is %d" %(x))
# Out:
# my age is 30
# my age is 31
# my age is 32
# my age is 33
# my age is 34
# my age is 35
# my age is 36
# my age is 37
# my age is 38
# my age is 39
# my age is 40
# my age is 41
# my age is 42
# my age is 43
# my age is 44

# %% [markdown]
# __Back to the ords_prods_merged__

# %%
ords_prods_merged.head(10)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
# 5   2398795        1             2          3                  7
# 6   2398795        1             2          3                  7
# 7   2398795        1             2          3                  7
# 8   2398795        1             2          3                  7
# 9   2398795        1             2          3                  7
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True       196.0                1.0
# 1                     NaN         True     14084.0                2.0
# ...

# %%
ords_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# 0    6252941
# 1    5696724
# 6    4530304
# 2    4243173
# 5    4236989
# 3    3868747
# 4    3812390
# Name: order_dow, dtype: int64

# %%
result = []

for value in ords_prods_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
ords_prods_merged['busiest_day'] = result

# %%
ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22575937
# Busiest day        6252941
# Least busy         3812390
# Name: busiest_day, dtype: int64

# %% [markdown]
# __TASK 4.7__ (i got this!!!)

# %%
#1. price_label and busiest_day are on the table
ords_prods_merged.head(5)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True       196.0                1.0
# 1                     NaN         True     14084.0                2.0
# 2                     NaN         True     12427.0                3.0
# 3                     NaN         True     26088.0                4.0
# 4                     NaN         True     26405.0                5.0
#
#    reordered                             product_name  aisle_id  \
# 0        0.0                                     Soda      77.0
# ...

# %%
#2.Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.
ords_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# 0    6252941
# 1    5696724
# 6    4530304
# 2    4243173
# 5    4236989
# 3    3868747
# 4    3812390
# Name: order_dow, dtype: int64

# %%
result = []

for value in ords_prods_merged["order_dow"]:
  if value == 0 or value == 1:
    result.append("Busiest days")
  elif value == 4 or value == 3:
    result.append("slowest days")
  else:
    result.append("Regularly busy days")

# %%
ords_prods_merged['busiest_days'] = result

# %%
#3. check the accuracy 
ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy days    13010466
# Busiest days           11949665
# slowest days            7681137
# Name: busiest_days, dtype: int64

# %%
#observation: the new collumn calculation in correct, busiest day is a combination of 0 & 1; regularly busy days is a total of 6,2 & 5 and the slowest days is the total of 3 & 4

# %%
ords_prods_merged.head(30)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2539329        1             1          2                  8
# 2    2539329        1             1          2                  8
# 3    2539329        1             1          2                  8
# 4    2539329        1             1          2                  8
# 5    2398795        1             2          3                  7
# 6    2398795        1             2          3                  7
# 7    2398795        1             2          3                  7
# 8    2398795        1             2          3                  7
# 9    2398795        1             2          3                  7
# 10   2398795        1             2          3                  7
# 11    473747        1             3          3                 12
# 12    473747        1             3          3                 12
# ...

# %% [markdown]
# #4.When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
#first let's check the list of hour when order is submitted
ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2781009
# 11    2755369
# 14    2709084
# 15    2682090
# 13    2680171
# 12    2637533
# 16    2554110
# 9     2471067
# 17    2104225
# 8     1729871
# 18    1649870
# 19    1268365
# 20     983232
# 7      897163
# 21     801052
# 22     638671
# 23     405051
# 6      292533
# 0      220337
# 1      116589
# 5       88661
# 2       69904
# 4       53636
# 3       51675
# Name: order_hour_of_day, dtype: int64

# %%
ords_prods_merged.shape
# Out:
# (32641268, 18)

# %%
result = []

for value in ords_prods_merged["order_hour_of_day"]:
  if value >= 9 and value <= 16:
    result.append("Most orders")
  elif value <= 6 or value == 23:
    result.append("Fewest orders")
  else:
    result.append("Average orders")

# %%
ords_prods_merged['busiest_period_of_day'] = result

# %%
#7.check % printing the accuracy
ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21270433
# Average orders    10072449
# Fewest orders      1298386
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods_merged.head(30)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2539329        1             1          2                  8
# 2    2539329        1             1          2                  8
# 3    2539329        1             1          2                  8
# 4    2539329        1             1          2                  8
# 5    2398795        1             2          3                  7
# 6    2398795        1             2          3                  7
# 7    2398795        1             2          3                  7
# 8    2398795        1             2          3                  7
# 9    2398795        1             2          3                  7
# 10   2398795        1             2          3                  7
# 11    473747        1             3          3                 12
# 12    473747        1             3          3                 12
# ...

# %%
#needed to delete the order_time_loc :-) failed attempt
ords_prods_merged.drop('order_time_loc',axis=1,inplace=True)

# %%
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True       196.0                1.0
# 1                     NaN         True     14084.0                2.0
# 2                     NaN         True     12427.0                3.0
# 3                     NaN         True     26088.0                4.0
# 4                     NaN         True     26405.0                5.0
#
#    reordered                             product_name  aisle_id  \
# 0        0.0                                     Soda      77.0
# ...

# %%
#exporting data frame as pickle size 
ords_prods_merged.to_pickle(r'/Users/rayruslijunior/11-2021 Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged_addition.pkl')
